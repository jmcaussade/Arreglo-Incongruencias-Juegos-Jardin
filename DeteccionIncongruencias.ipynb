# %% [markdown]
# <a href="https://colab.research.google.com/github/jmcaussade/Arreglo-Incongruencias-Juegos-Jardin/blob/main/DeteccionIncongruencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>IMPORTATIONS</h1>

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.7-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.7

# %%
import os
import pandas as pd
import numpy as np
from unidecode import unidecode

# %% [markdown]
# <h1>Connection to Google Drive</h1>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
##############################
### AQUÍ SE DEBE MODIFICAR ###
##############################

ruta = "/content/drive/MyDrive/Sodimac/Baterias/BATERIAS DE AUTO.xlsx"
df = pd.read_excel(ruta)

# %% [markdown]
# <h1>MAIN</h1>

# %% [markdown]
# Visualization

# %%
df

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# Manipulation

# %% [markdown]
# Transformation to long format of "Descripcion Local del Producto"

# %%
print(df[[ "Descripción Web"]])

# %%
##############################
### AQUÍ SE DEBE MODIFICAR ###
##############################


# restringiendo dataframe a columnas importantes
selected_columns = ["SKU - Chile", "Descripción Web", "Marca", "Capacidad Nominal", "Tipo de batería", "Arranque en frío", "Posición del borne", "Modelo"]
clean_df = df.loc[:, selected_columns]

# clean_df['Número de personas'] = clean_df['Número de personas'].replace([np.inf, -np.inf], np.nan).fillna(0)
# clean_df['Número de personas'] = clean_df['Número de personas'].astype(int).astype(str)

# %%
# Add new columns for each selected column without checking if the values exist creating the "Name column + appears"

for name_column in selected_columns[2:]:
    clean_df.insert(clean_df.columns.get_loc(name_column) + 1, f"{name_column} appears", None)

# Print the DataFrame with the new columns
clean_df

# %%
##############################
### AQUÍ SE DEBE MODIFICAR ###
##############################


#Checks if the value for each attributes appears
# Columnas con atributos obligatorios para buscar en desc web
selected_columns = ["Marca", "Capacidad Nominal", "Tipo de batería", "Arranque en frío", "Posición del borne", "Modelo"]

# Function to check if all values appear in the Descripción Web column in any case
def all_values_appear_in_web_description(row):
    description_web = unidecode(row["Descripción Web"]).lower()
    for col in selected_columns:
        value = unidecode(str(row[col])).lower()
        # if col == "Tipo de mobiliario jardín":
        #     aux = value.split(" ")
        #     if len(aux) == 4:
        #         value = aux[-2] + " " + aux[-1]
        #     else:
        #         value = aux[-1]
        # Set the corresponding boolean column to True or False
        row[f"{col} appears"] = value in description_web
    # Set the "AllValuesAppear" column based on the condition
    row['AllValuesAppear'] = all(row[f"{col} appears"] for col in selected_columns)
    return row

# Apply the function to each row
clean_df = clean_df.apply(all_values_appear_in_web_description, axis=1)

# %%
clean_df

# %%
# highlight  all True rows (all atributes are True)
def highlight_rows(row):
    if row['AllValuesAppear']:
        return ['background-color: lightgreen'] * len(row)
    else:
        return [''] * len(row)

# Apply the custom styles to the DataFrame
styled_df = clean_df.style.apply(highlight_rows, axis=1)

# Display the styled DataFrame
styled_df

# %%
# highlight False cells in red
def highlight_cells(value):
    if value is False:
        return 'background-color: red'
    elif value is True:
        return 'background-color: lightgreen'
    else:
        return ''

# Apply the custom styles to the DataFrame
styled_df = clean_df.style.applymap(highlight_cells, subset=pd.IndexSlice[:, [f"{col} appears" for col in selected_columns]])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T
row39_col7, #T_17164_row39_col13, #T_17164_row40_col5, #T_17164_row40_col7, #T_17164_row40_col13, #T_17164_row41_col5, #T_17164_row41_col7, #T_17164_row41_col13, #T_17164_row42_col5, #T_17164_row42_col7, #T_17164_row42_col13, #T_17164_row43_col5, #T_17164_row43_col7, #T_17164_row43_col13, #T_17164_row44_col5, #T_17164_row44_col7, #T_17164_row44_col13, #T_17164_row45_col5, #T_17164_row45_col7, #T_17164_row45_col13, #T_17164_row46_col5, #T_17164_row46_col7, #T_17164_row46_col13, #T_17164_row47_col5, #T_17164_row47_col7, #T_17164_row47_col13, #T_17164_row48_col5, #T_17164_row48_col7, #T_17164_row48_col13, #T_17164_row49_col5, #T_17164_row49_col7, #T_17164_row49_col13, #T_17164_row50_col5, #T_17164_row50_col7, #T_17164_row50_col13, #T_17164_row51_col5, #T_17164_row51_col7, #T_17164_row51_col13, #T_17164_row52_col5, #T_17164_row52_col7, #T_17164_row52_col13, #T_17164_row53_col5, #T_17164_row53_col7, #T_17164_row53_col13, #T_17164_row54_col5, #T_17164_row54_col7, #T_17164_row54_col13, #T_17164_row55_col5, #T_17164_row55_col7, #T_17164_row55_col13, #T_17164_row56_col5, #T_17164_row56_col7, #T_17164_row56_col13, #T_17164_row57_col5, #T_17164_row57_col7, #T_17164_row57_col13, #T_17164_row58_col5, #T_17164_row58_col7, #T_17164_row58_col13, #T_17164_row59_col5, #T_17164_row59_col7, #T_17164_row59_col13, #T_17164_row60_col5, #T_17164_row60_col7, #T_17164_row60_col13, #T_17164_row61_col5, #T_17164_row61_col7, #T_17164_row61_col13, #T_17164_row62_col5, #T_17164_row62_col7,  ...

# %% [markdown]
# <h1> Metrics by Column </h1>

# %%
# Assuming clean_df is your DataFrame with boolean columns
# Calculate and print the percentage of True values in each boolean column
for col in clean_df.columns:
    if clean_df[col].dtype == bool:  # Check if the column is boolean
        true_percentage = (clean_df[col] == True).mean() * 100
        print(f"{col} percentage: {true_percentage:.2f}%")
# Out:
# Capacidad Nominal appears percentage: 0.59%
# Tipo de batería appears percentage: 13.53%
# Arranque en frío appears percentage: 73.53%
# Posición del borne appears percentage: 93.53%
# Modelo appears percentage: 0.00%
# AllValuesAppear percentage: 0.00%

# %% [markdown]
# <h1>EXPORTING</h1>

# %%
##############################
### AQUÍ SE DEBE MODIFICAR ###
##############################

# Assuming clean_df is your DataFrame
output_file_path = "/content/drive/MyDrive/Sodimac/Refrigeradores/Results1.xlsx"

# Check if the file already exists
if os.path.exists(output_file_path):
    # Optionally, prompt the user or take appropriate action
    print(f"Warning: The file {output_file_path} already exists. It will be overwritten if the name is not changed.")
else:
  # Export the DataFrame to an Excel file
  clean_df.to_excel(output_file_path, index=False)
  print(f"DataFrame exported to {output_file_path}")
# Out:
# Warning: The file /content/drive/MyDrive/Sodimac/Sacos_de_Dormir/Results1.xlsx already exists. It will be overwritten if the name is not changed.
